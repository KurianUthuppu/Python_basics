# %%
# Importing requisite libraries
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
from datetime import date as dt

# %%
# Setting the path to the requisite folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path+'.\\','student*.csv'))

# Declaring empty dataframe and appending data from all files to the sheet
stud_df = pd.concat((pd.read_csv(file) for file in csv_files), ignore_index=True)

# %% [markdown]
# #  Data Analysis

# %%
# Give visibility on the top 5 rows along with headers
stud_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
stud_df.shape
# Out:
# (395, 33)

# %%
# Executes major statistical analysis
stud_df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
# Lists out the data types in each column
stud_df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# Removing white-space on the headers
stud_df.columns = stud_df.columns.str.strip()

# %%
# To identify and convert each column to the right data type; check again using dtype forumula
stud_df = stud_df.convert_dtypes()

# %%
stud_df.dtypes
# Out:
# school        string
# sex           string
# age            Int64
# address       string
# famsize       string
# Pstatus       string
# Medu           Int64
# Fedu           Int64
# Mjob          string
# Fjob          string
# reason        string
# guardian      string
# traveltime     Int64
# studytime      Int64
# failures       Int64
# schoolsup     string
# famsup        string
# paid          string
# activities    string
# nursery       string
# higher        string
# internet      string
# romantic      string
# famrel         Int64
# freetime       Int64
# goout          Int64
# Dalc           Int64
# Walc           Int64
# health         Int64
# absences       Int64
# G1             Int64
# G2             Int64
# G3             Int64
# dtype: object

# %%
# Dropping columns that aren't required
stud_df.drop(['reason','nursery'],axis='columns',inplace=True)

# Dropping rows with null values in G3
stud_df['G3'].dropna(inplace=True)

# %%
# Finding the no. of rows and columns
stud_df.shape
# Out:
# (395, 32)

# %%
# Findout average age of Female and Male students separately
age_mean = np.mean(stud_df['age'])
age_max = stud_df.age.max()
age_min = stud_df.age.min()
print("Mean age:",round(age_mean,2),"\nMax. Age: ",round(age_max,2),"\nMin age: ",round(age_min,2))
f_age_mean = np.mean(stud_df[stud_df['sex']=='F'].age)
m_age_mean = np.mean(stud_df[stud_df['sex']=='M'].age)
print("Mean age - Female:",round(f_age_mean,2),"\nMean age - Male:",round(m_age_mean,2))
# Out:
# Mean age: 16.7
# Max. Age:  22
# Min age:  15
# Mean age - Female: 16.73
# Mean age - Male: 16.66

# %%
# Findout average alcohol consumption score of Female and Male students separately with 75% weightage to weekday consumption and 25% to weekend consumption
alc_mean = np.mean(stud_df['Dalc']*0.75+stud_df['Walc']*0.25)
f_alc_mean = np.mean(stud_df[stud_df['sex']=='F'].Dalc*0.75+stud_df[stud_df['sex']=='F'].Walc*0.25)
m_alc_mean = np.mean(stud_df[stud_df['sex']=='M'].Dalc*0.75+stud_df[stud_df['sex']=='M'].Walc*0.25)
print("Mean alcohol score:",round(alc_mean,2),"\nMean alcohol score - Female:",round(f_alc_mean,2),"\nMean alcohol score - Male:",round(m_alc_mean,2))
# Out:
# Mean alcohol score: 1.68
# Mean alcohol score - Female: 1.43
# Mean alcohol score - Male: 1.97

# %%
# Find rows with null values in a particular column
null_set = stud_df[stud_df['address'].isnull()] # Can use isna() as well
null_set
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Find rows with no null values in a particular column
full_set = stud_df[stud_df['address'].notna()]
full_set
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  G3
# 0    ...      4         3      4     1    1      3        6   5   6   6
# 1    ...      5         3      3     1    1      3        4   5   5   6
# 2    ...      4         3      2     2    3      3       10   7   8  10
# 3    ...      3         2      2     1    1      5        2  15  14  15
# 4    ...      4         3      2     1    2      5        4   6  10  10
# ..   ...    ...       ...    ...   ...  ...    ...      ...  ..  ..  ..
# 390  ...      5         5      4     4    5      4       11   9   9   9
# 391  ...      2         4      5     3    4      2        3  14  16  16
# 392  ...      5         5      3     3    3      3        3  10   8   7
# 393  ...      4         4      1     3    4      5        0  11  12  10
# 394  ...      3         2      3     3    3      5        5   8   9   9
#
# [395 rows x 31 columns]

# %%
# Extract requisite columns using iloc
demo_set = stud_df.iloc[:,np.r_[0:3, 6:9, 13:30]]
demo_set
# Out:
#     school sex  age  Medu  Fedu      Mjob  failures schoolsup famsup paid  \
# 0       GP   F   18     4     4   at_home         0       yes     no   no
# 1       GP   F   17     1     1   at_home         0        no    yes   no
# 2       GP   F   15     1     1   at_home         3       yes     no  yes
# 3       GP   F   15     4     2    health         0        no    yes  yes
# 4       GP   F   16     3     3     other         0        no    yes  yes
# ..     ...  ..  ...   ...   ...       ...       ...       ...    ...  ...
# 390     MS   M   20     2     2  services         2        no    yes  yes
# 391     MS   M   17     3     1  services         0        no     no   no
# 392     MS   M   21     1     1     other         3        no     no   no
# 393     MS   M   18     3     2  services         0        no     no   no
# 394     MS   M   19     1     1     other         0        no     no   no
#
#      ... romantic famrel freetime goout  Dalc  Walc  health  absences  G1  G2
# 0    ...       no      4        3     4     1     1       3         6   5   6
# 1    ...       no      5        3     3     1     1       3         4   5   5
# 2    ...       no      4        3     2     2     3       3        10   7   8
# 3    ...      yes      3        2     2     1     1       5         2  15  14
# 4    ...       no      4        3     2     1     2       5         4   6  10
# ..   ...      ...    ...      ...   ...   ...   ...     ...       ...  ..  ..
# 390  ...       no      5        5     4     4     5       4        11   9   9
# 391  ...       no      2        4     5     3     4       2         3  14  16
# 392  ...       no      5        5     3     3     3       3         3  10   8
# 393  ...       no      4        4     1     3     4       5         0  11  12
# 394  ...       no      3        2     3     3     3       5         5   8   9
#
# [395 rows x 23 columns]

# %%
# Splitting the string
split_string = stud_df['Mjob'].str.split('e').str[0]
split_string
# Out:
# 0      at_hom
# 1      at_hom
# 2      at_hom
# 3           h
# 4         oth
#         ...
# 390         s
# 391         s
# 392       oth
# 393         s
# 394       oth
# Name: Mjob, Length: 395, dtype: object

# %%
# Column Insertion
stud_df.insert(loc=4,column='Split-String', value=split_string)
stud_df
# Out:
#     school sex  age address Split-String famsize Pstatus  Medu  Fedu  \
# 0       GP   F   18       U       at_hom     GT3       A     4     4
# 1       GP   F   17       U       at_hom     GT3       T     1     1
# 2       GP   F   15       U       at_hom     LE3       T     1     1
# 3       GP   F   15       U            h     GT3       T     4     2
# 4       GP   F   16       U          oth     GT3       T     3     3
# ..     ...  ..  ...     ...          ...     ...     ...   ...   ...
# 390     MS   M   20       U            s     LE3       A     2     2
# 391     MS   M   17       U            s     LE3       T     3     1
# 392     MS   M   21       R          oth     GT3       T     1     1
# 393     MS   M   18       R            s     LE3       T     3     2
# 394     MS   M   19       U          oth     LE3       T     1     1
#
#          Mjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# 0     at_home  ...      4        3      4     1     1      3        6   5   6
# 1     at_home  ...      5        3      3     1     1      3        4   5   5
# 2     at_home  ...      4        3      2     2     3      3       10   7   8
# 3      health  ...      3        2      2     1     1      5        2  15  14
# 4       other  ...      4        3      2     1     2      5        4   6  10
# ..        ...  ...    ...      ...    ...   ...   ...    ...      ...  ..  ..
# 390  services  ...      5        5      4     4     5      4       11   9   9
# 391  services  ...      2        4      5     3     4      2        3  14  16
# 392     other  ...      5        5      3     3     3      3        3  10   8
# 393  services  ...      4        4      1     3     4      5        0  11  12
# 394     other  ...      3        2      3     3     3      5        5   8   9
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [395 rows x 32 columns]

# %%
stud_df.drop('Split-String', axis='columns', inplace=True) # Dropping the extra column added for demo
# Rearranging columns
column_names = ['Mjob','Fjob','school','Dalc','absences','sex','famsize']
demo_df = stud_df.reindex(column_names, axis='columns')
demo_df
# Out:
#          Mjob      Fjob school  Dalc  absences sex famsize
# 0     at_home   teacher     GP     1         6   F     GT3
# 1     at_home     other     GP     1         4   F     GT3
# 2     at_home     other     GP     2        10   F     LE3
# 3      health  services     GP     1         2   F     GT3
# 4       other     other     GP     1         4   F     GT3
# ..        ...       ...    ...   ...       ...  ..     ...
# 390  services  services     MS     4        11   M     LE3
# 391  services  services     MS     3         3   M     LE3
# 392     other     other     MS     3         3   M     GT3
# 393  services     other     MS     3         0   M     LE3
# 394     other   at_home     MS     3         5   M     LE3
#
# [395 rows x 7 columns]

# %%
# Renaming a column
demo_df.rename(columns={'Mjob':'Mothers job'}, inplace=True)
demo_df.drop(['school','Dalc','absences','sex','famsize'],axis='columns',inplace=True)
demo_df
# Out:
#     Mothers job      Fjob
# 0       at_home   teacher
# 1       at_home     other
# 2       at_home     other
# 3        health  services
# 4         other     other
# ..          ...       ...
# 390    services  services
# 391    services  services
# 392       other     other
# 393    services     other
# 394       other   at_home
#
# [395 rows x 2 columns]

# %%
# Merging 2 columns
jobs_merged_column = demo_df['Mothers job']+' & '+ demo_df['Fjob']
jobs_merged_column
# Out:
# 0        at_home & teacher
# 1          at_home & other
# 2          at_home & other
# 3        health & services
# 4            other & other
#               ...
# 390    services & services
# 391    services & services
# 392          other & other
# 393       services & other
# 394        other & at_home
# Length: 395, dtype: string

# %%
demo_df.insert(loc=2, column='Job_merged',value=jobs_merged_column)
demo_df
# Out:
#     Mothers job      Fjob           Job_merged
# 0       at_home   teacher    at_home & teacher
# 1       at_home     other      at_home & other
# 2       at_home     other      at_home & other
# 3        health  services    health & services
# 4         other     other        other & other
# ..          ...       ...                  ...
# 390    services  services  services & services
# 391    services  services  services & services
# 392       other     other        other & other
# 393    services     other     services & other
# 394       other   at_home      other & at_home
#
# [395 rows x 3 columns]

# %%
# Merging two datasets
#new_df = pd.merge(stud_df,demo_df,on='uid',how='left') # Merging on common column with unique identifier if present
new_df = pd.merge(stud_df,demo_df,left_index=True,right_index=True)
# The above can be achieved in left join mode via df1.join(df2)
new_df
# Out:
#      Sl.No. school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1     GP   F   15       R     GT3       T     3     4  services
# 1         2     GP   M   15       R     GT3       T     3     2     other
# 2         3     GP   M   15       U     GT3       T     4     2     other
# 3         4     GP   M   15       R     GT3       T     2     3   at_home
# 4         5     GP   F   15       U     GT3       T     4     2    health
# ..      ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390     391     MS   F   20       U     GT3       T     4     2    health
# 391     392     GP   M   20       U     GT3       A     3     2  services
# 392     393     MS   M   20       U     LE3       A     2     2  services
# 393     394     MS   M   21       R     GT3       T     1     1     other
# 394     395     GP   M   22       U     GT3       T     3     1  services
#
#      ... Dalc Walc  health  absences  G1  G2  G3 Mothers job    Fjob_y  \
# 0    ...    2    2       5         0  12   0   0     at_home   teacher
# 1    ...    1    4       3         6   5   9   7     at_home     other
# 2    ...    1    1       3         0  10  10  10     at_home     other
# 3    ...    1    1       1         2  11   8   8      health  services
# 4    ...    1    1       5         2  15  14  15       other     other
# ..   ...  ...  ...     ...       ...  ..  ..  ..         ...       ...
# 390  ...    1    1       3         4  15  14  15    services  services
# 391  ...    1    1       5         0  17  18  18    services  services
# 392  ...    4    5       4        11   9   9   9       other     other
# 393  ...    3    3       3         3  10   8   7    services     other
# 394  ...    5    5       1        16   6   8   8       other   at_home
#
#               Job_merged
# 0      at_home & teacher
# 1        at_home & other
# 2        at_home & other
# 3      health & services
# 4          other & other
# ..                   ...
# 390  services & services
# 391  services & services
# 392        other & other
# 393     services & other
# 394      other & at_home
#
# [395 rows x 35 columns]

# %%
# Converting string to requisite format
stud_df['famsize'] = stud_df['famsize'].astype(str).str.zfill(4)
stud_df['famsize']
# Out:
# 0      0GT3
# 1      0GT3
# 2      0LE3
# 3      0GT3
# 4      0GT3
#        ...
# 390    0LE3
# 391    0LE3
# 392    0GT3
# 393    0LE3
# 394    0LE3
# Name: famsize, Length: 395, dtype: object

# %%
# Using lambda to identify substrings
stud_df['famsize'] = stud_df['famsize'].astype(str).map(lambda x: x[1:])
stud_df['famsize']
# Out:
# 0      GT3
# 1      GT3
# 2      LE3
# 3      GT3
# 4      GT3
#       ...
# 390    LE3
# 391    LE3
# 392    GT3
# 393    LE3
# 394    LE3
# Name: famsize, Length: 395, dtype: object

# %%
# Filter out rows with multiple conditions using & or |
stud_df[(stud_df['sex']=='M') & (stud_df['Walc']>4)].shape[0]
# Out:
# 24

# %%
# Filter out rows with multiple conditions using & or |
stud_df[(stud_df['sex']=='F') | (stud_df['Walc']>4)].shape[0]
# Out:
# 232

# %%
# Append to a dataframe
append_df = stud_df[stud_df['sex']=='M']

# %%
new_df =stud_df
new_df = new_df.append(append_df)
new_df
# Out:
#      Sl.No. school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1     GP   F   15       R     GT3       T     3     4  services
# 1         2     GP   M   15       R     GT3       T     3     2     other
# 2         3     GP   M   15       U     GT3       T     4     2     other
# 3         4     GP   M   15       R     GT3       T     2     3   at_home
# 4         5     GP   F   15       U     GT3       T     4     2    health
# ..      ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 389     390     GP   M   19       U     GT3       T     1     2     other
# 391     392     GP   M   20       U     GT3       A     3     2  services
# 392     393     MS   M   20       U     LE3       A     2     2  services
# 393     394     MS   M   21       R     GT3       T     1     1     other
# 394     395     GP   M   22       U     GT3       T     3     1  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        2      2     2     2      5        0  12   0   0
# 1    ...      4        4      4     1     4      3        6   5   9   7
# 2    ...      3        3      3     1     1      3        0  10  10  10
# 3    ...      4        4      4     1     1      1        2  11   8   8
# 4    ...      3        2      2     1     1      5        2  15  14  15
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 389  ...      4        5      2     2     2      4        3  13  11  11
# 391  ...      5        5      3     1     1      5        0  17  18  18
# 392  ...      5        5      4     4     5      4       11   9   9   9
# 393  ...      5        5      3     3     3      3        3  10   8   7
# 394  ...      5        4      5     5     5      1       16   6   8   8
#
# [582 rows x 32 columns]

# %%
# Sorting the rows and inserting serial no.
stud_df.sort_values(by='age', inplace=True)
stud_df.insert(loc=0,column='Sl.No.',value=np.arange(1,len(stud_df)+1))
stud_df.reset_index(inplace=True, drop=True)
stud_df
# Out:
#      Sl.No. school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1     GP   F   15       R     GT3       T     3     4  services
# 1         2     GP   M   15       R     GT3       T     3     2     other
# 2         3     GP   M   15       U     GT3       T     4     2     other
# 3         4     GP   M   15       R     GT3       T     2     3   at_home
# 4         5     GP   F   15       U     GT3       T     4     2    health
# ..      ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390     391     MS   F   20       U     GT3       T     4     2    health
# 391     392     GP   M   20       U     GT3       A     3     2  services
# 392     393     MS   M   20       U     LE3       A     2     2  services
# 393     394     MS   M   21       R     GT3       T     1     1     other
# 394     395     GP   M   22       U     GT3       T     3     1  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        2      2     2     2      5        0  12   0   0
# 1    ...      4        4      4     1     4      3        6   5   9   7
# 2    ...      3        3      3     1     1      3        0  10  10  10
# 3    ...      4        4      4     1     1      1        2  11   8   8
# 4    ...      3        2      2     1     1      5        2  15  14  15
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        4      3     1     1      3        4  15  14  15
# 391  ...      5        5      3     1     1      5        0  17  18  18
# 392  ...      5        5      4     4     5      4       11   9   9   9
# 393  ...      5        5      3     3     3      3        3  10   8   7
# 394  ...      5        4      5     5     5      1       16   6   8   8
#
# [395 rows x 32 columns]

# %%
# Writing to a CSV or Excel file in the current folder
path = os.path.join(os.getcwd(),'stud_Alc_worked.csv')
stud_df.to_csv(path, index=False)
path = os.path.join(os.getcwd(),'stud_Alc_worked.xlsx')
stud_df.to_excel(path, index=False)

# %%
# Using functions
def get_col_widths(dataframe):
    # First we find the maximum length of the index column   
    idx_max = max([len(str(s)) for s in dataframe.index.values] + [len(str(dataframe.index.name))])
    # Then, we concatenate this to the max of the lengths of column name and its values for each column, left to right
    return [idx_max] + [max([len(str(s)) for s in dataframe[col].values] + [len(col)]) for col in dataframe.columns]

write_date = dt.today()
path = os.path.join(os.getcwd()+'.//stud_alc_kaggle'+' I '+write_date.strftime('%d-%b-%Y')+'.xlsx')
with pd.ExcelWriter(path, engine='xlsxwriter') as writer:
    stud_df.to_excel(writer, index=False, sheet_name='Data', startcol=1, startrow=1)
    
    workbook = writer.book
    worksheet = writer.sheets['Data']
    
    for i, width in enumerate(get_col_widths(stud_df)):
        worksheet.set_column(i, i, width)
    
    writer.save()

# %%
# Plotting simple histogram of the age
plt.hist(stud_df.age)
plt.show()

# %%
# Plotting heatmap between all variable to understand the correlation
plt.figure(figsize=(20,10))
sns.heatmap(stud_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Removing the zero values
temp = stud_df[(stud_df.G3!=0) & (stud_df.G1!=0)]

# %%
# Converting to float datatype
temp.G1 = temp.G1.astype(float)
temp.G3 = temp.G3.astype(float)
# Out:
# C:\Users\Stellapps\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Get coeffs of linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(temp['G1'],temp['G3'])
plt.figure(figsize=(15,10))

# Use line_kws to set line label for legend
ax = sns.regplot(x="G1", y="G3", data=temp, color='b',
 line_kws={'label':"y={0:.2f}x+{1:.2f}".format(slope,intercept)})

# Plot legend
ax.legend()

plt.show()

# %%
# Executing the scatter plot along with linear regression
sns.set_style('whit
              egrid')
reg = sns.lmplot(x='G1', y='G3', data=temp, hue = 'sex', markers =['o', 'v'],height=7, aspect=1.5)
